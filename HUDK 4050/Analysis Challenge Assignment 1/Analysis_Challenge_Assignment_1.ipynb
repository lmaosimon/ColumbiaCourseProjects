# %% [markdown]
# &nbsp;

# %% [markdown]
# # <center>Analysis Challenge Assignment 1</center>
# ### <center>Alex School Selction</center>
# <center>Author: Simon Chen, Jianan Dingqian</center>
# <center>Time: Sep 28, 2021</center>

# %% [markdown]
# #### **1. Criteria**

# %% [markdown]
# Alex wants to pursue a degree in Education. She wants to find the best school within U.S. with following requirements: <br>
# 1. Safety (low crime)
# 2. Urban (big city preferred)
# 3. Diversity (diverse culture)
# 4. Quality (decent program, but need to be defined)

# %% [markdown]
# #### **2. Tasks**

# %% [markdown]
# 1. Create a dataset with limited information(e.g., crime rate, admission rate) to meet criteria.
# 2. Keep record of code and descriptions to explain designed approach.
# 3. Create a rule to rank the schools in consideration of all of Alex criteria taken together. (Bonus)

# %% [markdown]
# #### **3. Import**

# %% [markdown]
# ###### a. Crime data

# %%
# Import libraries.
import pandas as pd
# Reading the crime data in 2015 from shareable link into Pandas.
crime_data = pd.read_csv('Crime_2015.csv')
crime_data
# Out:
#                                               MSA ViolentCrime  Murder  Rape  \
# 0                              Abilene, TX M.S.A.        412.5     5.3  56.0
# 1                                Akron, OH M.S.A.        238.4     5.1  38.2
# 2                               Albany, GA M.S.A.        667.9     7.8  30.4
# 3                               Albany, OR M.S.A.        114.3     2.5  28.2
# 4                          Albuquerque, NM M.S.A.        792.6     6.1  63.8
# ..                                            ...          ...     ...   ...
# 373                   Guayama, Puerto Rico M.S.A.        251.6    11.4   6.3
# 374                  Mayaguez, Puerto Rico M.S.A.        237.5    11.5   5.2
# 375                     Ponce, Puerto Rico M.S.A.        231.4    18.0   5.0
# 376                San German, Puerto Rico M.S.A.         92.1     5.4   4.6
# 377  San Juan-Carolina-Caguas, Puerto Rico M.S.A.        262.0    20.6   4.9
#
#      Robbery  AggravatedAssault PropertyCrime Burglary    Theft  \
# 0       78.4              272.8       3,609.0    852.0  2,493.6
# 1       75.2              119.8       2,552.4    575.3  1,853.0
# 2      157.9              471.8       3,894.1  1,099.6  2,652.8
# 3       20.7               63.0       3,208.4    484.6  2,476.1
# 4      206.7              516.0       4,607.8    883.4  3,047.6
# ..       ...                ...           ...      ...      ...
# 373     74.6              159.3         823.2    265.5    531.1
# 374     82.3              138.6       1,320.0    377.1    861.6
# 375     66.2              142.2         885.0    214.4    632.4
# 376     16.1               66.0         420.0    168.9    226.5
# 377    157.8               78.7       1,281.2    281.8    835.0
#
#      MotorVehicleTheft                                         State  \
# 0                263.4                                            TX
# 1                124.1                                            OH
# 2                141.7                                            GA
# 3                247.7                                            OR
# 4                676.9                                            NM
# ..                 ...                                           ...
# 373               26.6                   Guayama, Puerto Rico M.S.A.
# 374               81.3                  Mayaguez, Puerto Rico M.S.A.
# 375               38.1                     Ponce, Puerto Rico M.S.A.
# 376               24.6                San German, Puerto Rico M.S.A.
# 377              164.3  San Juan-Carolina-Caguas, Puerto Rico M.S.A.
#
#             City
# 0        Abilene
# 1          Akron
# 2         Albany
# 3         Albany
# 4    Albuquerque
# ..           ...
# 373      Guayama
# 374     Mayaguez
# 375        Ponce
# 376   San German
# 377     San Juan
#
# [378 rows x 12 columns]

# %% [markdown]
# ###### b. College Scorecard data

# %%
# Reading College Scorecard data in pandas df.
college_data = pd.read_csv('CollegeScorecard.csv')
college_data
# Out:
# /Users/simon/opt/anaconda3/envs/HUDK4050/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (7,9,1427,1542,1561,1575,1725,1726,1727,1728) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         UNITID    OPEID  opeid6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7799  48285703   157107    1571
# 7800  48285704   157101    1571
# 7801  48285705   157105    1571
# 7802  48285706   157100    1571
# 7803  48285707   157103    1571
#
#                                              INSTNM            CITY STABBR  \
# 0                          Alabama A & M University          Normal     AL
# 1               University of Alabama at Birmingham      Birmingham     AL
# 2                                Amridge University      Montgomery     AL
# 3               University of Alabama in Huntsville      Huntsville     AL
# 4                          Alabama State University      Montgomery     AL
# ...                                             ...             ...    ...
# 7799       Georgia Military College-Columbus Campus        Columbus     GA
# 7800       Georgia Military College-Valdosta Campus        Valdosta     GA
# 7801  Georgia Military College-Warner Robins Campus   Warner Robins     GA
# 7802                Georgia Military College-Online   Milledgeville     GA
# 7803        Georgia Military College-Stone Mountain  Stone Mountain     GA
#
#              ZIP                                       AccredAgency  \
# 0          35762  Southern Association of Colleges and Schools C...
# 1     35294-0110  Southern Association of Colleges and Schools C...
# 2     36117-3553  Southern Association of Colleges and Schools C...
# 3          35899  Southern Association of Colleges and Schools C...
# 4     36104-0271  Southern Association of Colleges and Schools C...
# ...          ...                                                ...
# 7799       31909                                                NaN
# 7800       31605                                                NaN
# 7801       31093                                                NaN
# 7802       31061                                                NaN
# 7803       30083                                                NaN
#
#                              INSTURL  \
# 0                      www.aamu.edu/
# 1                        www.uab.edu
# 2          www.amridgeuniversity.edu
# 3                        www.uah.edu
# 4     www.alasu.edu/email/index.aspx
# ...                              ...
# 7799   http://columbus.gmc.cc.ga.us/
# 7800   http://valdosta.gmc.cc.ga.us/
# 7801     http://robins.gmc.cc.ga.us/
# 7802     http://online.gmc.cc.ga.us/
# 7803   http://fairburn.gmc.cc.ga.us/
#
#                                                  NPCURL  ...  \
# 0        galileo.aamu.edu/netpricecalculator/npcalc.htm  ...
# 1       www.collegeportraits.org/AL/UAB/estimator/agree  ...
# 2     tcc.noellevitz.com/(S(miwoihs5stz5cpyifh4nczu0...  ...
# 3                                       finaid.uah.edu/  ...
# 4     www.alasu.edu/cost-aid/forms/calculator/index....  ...
# ...                                                 ...  ...
# 7799                                                NaN  ...
# 7800                                                NaN  ...
# 7801                                                NaN  ...
# 7802                                                NaN  ...
# 7803                                                NaN  ...
#
#       PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0           0.443586698337           0.45251396648          0.484818805093
# 1           0.732297852901          0.795454545455          0.760521885522
# 2           0.600877192982                   0.775          0.610465116279
# 3           0.738341968912           0.85140562249          0.768378650554
# 4           0.320016820858          0.380829015544          0.364423717522
# ...                    ...                     ...                     ...
# 7799        0.427891480248          0.607753705815          0.490091055169
# 7800        0.427891480248          0.607753705815          0.490091055169
# 7801        0.427891480248          0.607753705815          0.490091055169
# 7802        0.427891480248          0.607753705815          0.490091055169
# 7803        0.427891480248          0.607753705815          0.490091055169
#
#       MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0                    0.406            0.423580786026
# 1           0.755344418052            0.751552795031
# 2           0.686567164179            0.632653061224
# 3           0.798440979955            0.778156996587
# 4           0.286530612245            0.315737051793
# ...                    ...                       ...
# 7799        0.461751152074            0.490384615385
# 7800        0.461751152074            0.490384615385
# 7801        0.461751152074            0.490384615385
# 7802        0.461751152074            0.490384615385
# 7803        0.461751152074            0.490384615385
#
#       NOTFIRSTGEN_RPY_3YR_RT_SUPP  C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP  \
# 0                  0.442452830189                  NaN    0.30871831265508
# 1                  0.765074770863                  NaN    0.50854980789381
# 2                            0.65                  NaN   PrivacySuppressed
# 3                  0.791666666667                  NaN    0.47821134615384
# 4                  0.334633385335                  NaN    0.25748195545488
# ...                           ...                  ...                 ...
# 7799               0.495152870992                  NaN                 NaN
# 7800               0.495152870992                  NaN                 NaN
# 7801               0.495152870992                  NaN                 NaN
# 7802               0.495152870992                  NaN                 NaN
# 7803               0.495152870992                  NaN                 NaN
#
#       C200_L4_POOLED_SUPP  C200_4_POOLED_SUPP
# 0                     NaN    0.35168556430446
# 1                     NaN     0.4730923834537
# 2                     NaN   PrivacySuppressed
# 3                     NaN    0.49412939796716
# 4                     NaN    0.29365162671232
# ...                   ...                 ...
# 7799                  NaN                 NaN
# 7800                  NaN                 NaN
# 7801                  NaN                 NaN
# 7802                  NaN                 NaN
# 7803                  NaN                 NaN
#
# [7804 rows x 1729 columns]

# %%
# Change STABBR to State
college_data.rename({'CITY': 'City', 'STABBR': 'State'})
# Out:
#         UNITID    OPEID  opeid6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7799  48285703   157107    1571
# 7800  48285704   157101    1571
# 7801  48285705   157105    1571
# 7802  48285706   157100    1571
# 7803  48285707   157103    1571
#
#                                              INSTNM            CITY STABBR  \
# 0                          Alabama A & M University          Normal     AL
# 1               University of Alabama at Birmingham      Birmingham     AL
# 2                                Amridge University      Montgomery     AL
# 3               University of Alabama in Huntsville      Huntsville     AL
# 4                          Alabama State University      Montgomery     AL
# ...                                             ...             ...    ...
# 7799       Georgia Military College-Columbus Campus        Columbus     GA
# 7800       Georgia Military College-Valdosta Campus        Valdosta     GA
# 7801  Georgia Military College-Warner Robins Campus   Warner Robins     GA
# 7802                Georgia Military College-Online   Milledgeville     GA
# 7803        Georgia Military College-Stone Mountain  Stone Mountain     GA
#
#              ZIP                                       AccredAgency  \
# 0          35762  Southern Association of Colleges and Schools C...
# 1     35294-0110  Southern Association of Colleges and Schools C...
# 2     36117-3553  Southern Association of Colleges and Schools C...
# 3          35899  Southern Association of Colleges and Schools C...
# 4     36104-0271  Southern Association of Colleges and Schools C...
# ...          ...                                                ...
# 7799       31909                                                NaN
# 7800       31605                                                NaN
# 7801       31093                                                NaN
# 7802       31061                                                NaN
# 7803       30083                                                NaN
#
#                              INSTURL  \
# 0                      www.aamu.edu/
# 1                        www.uab.edu
# 2          www.amridgeuniversity.edu
# 3                        www.uah.edu
# 4     www.alasu.edu/email/index.aspx
# ...                              ...
# 7799   http://columbus.gmc.cc.ga.us/
# 7800   http://valdosta.gmc.cc.ga.us/
# 7801     http://robins.gmc.cc.ga.us/
# 7802     http://online.gmc.cc.ga.us/
# 7803   http://fairburn.gmc.cc.ga.us/
#
#                                                  NPCURL  ...  \
# 0        galileo.aamu.edu/netpricecalculator/npcalc.htm  ...
# 1       www.collegeportraits.org/AL/UAB/estimator/agree  ...
# 2     tcc.noellevitz.com/(S(miwoihs5stz5cpyifh4nczu0...  ...
# 3                                       finaid.uah.edu/  ...
# 4     www.alasu.edu/cost-aid/forms/calculator/index....  ...
# ...                                                 ...  ...
# 7799                                                NaN  ...
# 7800                                                NaN  ...
# 7801                                                NaN  ...
# 7802                                                NaN  ...
# 7803                                                NaN  ...
#
#       PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0           0.443586698337           0.45251396648          0.484818805093
# 1           0.732297852901          0.795454545455          0.760521885522
# 2           0.600877192982                   0.775          0.610465116279
# 3           0.738341968912           0.85140562249          0.768378650554
# 4           0.320016820858          0.380829015544          0.364423717522
# ...                    ...                     ...                     ...
# 7799        0.427891480248          0.607753705815          0.490091055169
# 7800        0.427891480248          0.607753705815          0.490091055169
# 7801        0.427891480248          0.607753705815          0.490091055169
# 7802        0.427891480248          0.607753705815          0.490091055169
# 7803        0.427891480248          0.607753705815          0.490091055169
#
#       MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0                    0.406            0.423580786026
# 1           0.755344418052            0.751552795031
# 2           0.686567164179            0.632653061224
# 3           0.798440979955            0.778156996587
# 4           0.286530612245            0.315737051793
# ...                    ...                       ...
# 7799        0.461751152074            0.490384615385
# 7800        0.461751152074            0.490384615385
# 7801        0.461751152074            0.490384615385
# 7802        0.461751152074            0.490384615385
# 7803        0.461751152074            0.490384615385
#
#       NOTFIRSTGEN_RPY_3YR_RT_SUPP  C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP  \
# 0                  0.442452830189                  NaN    0.30871831265508
# 1                  0.765074770863                  NaN    0.50854980789381
# 2                            0.65                  NaN   PrivacySuppressed
# 3                  0.791666666667                  NaN    0.47821134615384
# 4                  0.334633385335                  NaN    0.25748195545488
# ...                           ...                  ...                 ...
# 7799               0.495152870992                  NaN                 NaN
# 7800               0.495152870992                  NaN                 NaN
# 7801               0.495152870992                  NaN                 NaN
# 7802               0.495152870992                  NaN                 NaN
# 7803               0.495152870992                  NaN                 NaN
#
#       C200_L4_POOLED_SUPP  C200_4_POOLED_SUPP
# 0                     NaN    0.35168556430446
# 1                     NaN     0.4730923834537
# 2                     NaN   PrivacySuppressed
# 3                     NaN    0.49412939796716
# 4                     NaN    0.29365162671232
# ...                   ...                 ...
# 7799                  NaN                 NaN
# 7800                  NaN                 NaN
# 7801                  NaN                 NaN
# 7802                  NaN                 NaN
# 7803                  NaN                 NaN
#
# [7804 rows x 1729 columns]

# %% [markdown]
# #### **4. Cleaning and Processing data**

# %% [markdown]
# ###### a. Merge datasets

# %%
# Then we rank the score to get a SafetyScore
# Since the reports number is the rates of reported offenses per 100,000 population.
# So we could just sum them up for each city to get the total rates by creating a new column rates.
crime_data['rates'] = crime_data.sum(axis=1)

# Merge two datasets by States and City.
combined_data = pd.merge(college_data, crime_data, on = ['State', 'City'])

# This table is now arranging cities from Hige crime rate to Low crime rate
crime_data = crime_data.sort_values(by='rates',ascending=False)
# Out:
# /var/folders/dk/0mc07v5d6_76957h6trqmgzh0000gn/T/ipykernel_5579/122636254.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   crime_data['rates'] = crime_data.sum(axis=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/dk/0mc07v5d6_76957h6trqmgzh0000gn/T/ipykernel_5579/122636254.py in <module>
#       5
#       6 # Merge two datasets by States and City.
# ----> 7 combined_data = pd.merge(college_data, crime_data, on = ['State', 'City'])
#       8
#       9 # This table is now arranging cities from Hige crime rate to Low crime rate
#
# ~/opt/anaconda3/envs/HUDK4050/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     103     validate: str | None = None,
#     104 ) -> DataFrame:
# --> 105     op = _MergeOperation(
#     106         left,
#     107         right,
#
# ~/opt/anaconda3/envs/HUDK4050/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696             self.right_join_keys,
#     697             self.join_names,
# --> 698         ) = self._get_merge_keys()
#     699
#     700         # validate the merge keys dtypes. We may need to coerce
#
# ~/opt/anaconda3/envs/HUDK4050/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1106                         right_keys.append(rk)
#    1107                     if lk is not None:
# -> 1108                         left_keys.append(left._get_label_or_level_values(lk))
#    1109                         join_names.append(lk)
#    1110                     else:
#
# ~/opt/anaconda3/envs/HUDK4050/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'State'

# %% [markdown]
# ###### b. College Scorecard data

# %% [markdown]
# *Urban*
